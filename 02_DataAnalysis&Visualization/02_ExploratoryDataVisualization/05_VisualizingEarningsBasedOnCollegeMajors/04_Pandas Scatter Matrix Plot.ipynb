# %%
# %matplotlib inline
import pandas as pd
import matplotlib
from pandas.tools.plotting import scatter_matrix 

recent_grads = pd.read_csv('recent-grads.csv')

scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027AE64E8CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027AE67A9FD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027AE67B8DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027AE6852438>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027AE6B23F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027AE6BB7BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027AE6BC8EB8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027AE6C83CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027AE6CE94A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027AE6CE94E0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027AE6F41E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027AE6FBFB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027AE70264A8>]], dtype=object)
