# %%
# %matplotlib inline
import pandas as pd
import matplotlib

# *******************
# Read the dataset into a DataFrame and start exploring the data

recent_grads = pd.read_csv('recent-grads.csv')

# We can access the underlying matplotlib Axes object by 
# assigning the return value to a variable

bn = 25

hst = recent_grads['Sample_size'].hist(bins=bn, range=(0,5000))
hst.set_title('Sample Size Distributation')

# %%
hst = recent_grads['Median'].hist(bins=bn)
hst.set_title('Median Distributation')

# %%
hst = recent_grads['Employed'].hist(bins=bn)
hst.set_title('Employed Distributation')

# %%
hst = recent_grads['Full_time'].hist(bins=bn)
hst.set_title('Full_time Distributation')

# %%
hst = recent_grads['ShareWomen'].hist(bins=bn)
hst.set_title('ShareWomen Distributation')

# %%
hst = recent_grads['Unemployment_rate'].hist(bins=bn)
hst.set_title('Unemployment_rate Distributation')

# %%
hst = recent_grads['Men'].hist(bins=bn)
hst.set_title('Men Distributation')

# %%
hst = recent_grads['Women'].hist(bins=bn)
hst.set_title('Women Distributation')
