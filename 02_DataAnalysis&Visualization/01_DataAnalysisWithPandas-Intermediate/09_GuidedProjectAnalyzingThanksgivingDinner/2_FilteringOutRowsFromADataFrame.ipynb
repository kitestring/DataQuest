# %%
import pandas as pd
data = pd.read_csv('thanksgiving-2015-poll-data.csv', encoding="Latin-1")

# Use the pandas.Series.value_counts() method to display counts of how
# many times each category occurs in the Do you celebrate Thanksgiving? column.
counts_celebrate_tks_gvn = data['Do you celebrate Thanksgiving?'].value_counts()
print(counts_celebrate_tks_gvn)

# Filter out any rows in data where the response to Do you celebrate Thanksgiving?
# is not Yes. At the end, all of the values in the Do you celebrate Thanksgiving? column of data should be Yes
yes_celebrate_tks_gvn_rows = data[data['Do you celebrate Thanksgiving?'] == 'Yes']
print("\nGut check, this number (%d) should be equal to 980 which is the number of 'Yes'\n" % yes_celebrate_tks_gvn_rows.shape[0])
print(yes_celebrate_tks_gvn_rows)
# Out:
# Yes    980
# No      78
# Name: Do you celebrate Thanksgiving?, dtype: int64
#
# Gut check, this number (980) should be equal to 980 which is the number of 'Yes'
#
#       RespondentID Do you celebrate Thanksgiving?  \
# 0       4337954960                            Yes
# 1       4337951949                            Yes
# 2       4337935621                            Yes
# 3       4337933040                            Yes
# 4       4337931983                            Yes
# 5       4337929779                            Yes
# 6       4337924420                            Yes
# 7       4337916002                            Yes
# 8       4337914977                            Yes
# 9       4337899817                            Yes
# 11      4337893416                            Yes
# 12      4337888291                            Yes
# 13      4337878450                            Yes
# 14      4337878351                            Yes
# ...
